# %%
import matplotlib.pyplot as plt

x = list(range(0,335))
y = [791.4283366, 791.4283366 ,791.4283366
,791.4283366
,791.4283366
,791.0283366
,791.0283366
,791.0283366
,791.0283366
,791.0283366
,790.5283366
,790.5283366
,790.5283366
,790.5283366
,790.5283366
,791.0283366
,791.0283366
,791.0283366
,791.0283366
,791.0283366
,791.4283366
,791.4283366
,791.4283366
,791.4283366
,791.4283366
,791.4283366
,791.4283366
,791.8283366
,791.8283366
,791.4283366
,791.8283366
,791.8283366
,791.8283366
,791.8283366
,791.8283366
,791.4283366
,791.4283366
,791.8283366
,791.8283366
,791.8283366
,791.8283366
,791.8283366
,791.8283366
,791.4283366
,792.2283366
,791.8283366
,792.2283366
,792.2283366
,792.2283366
,792.2283366
,792.2283366
,792.2283366
,792.2283366
,792.2283366
,792.2283366
,792.2283366
,792.2283366
,792.7283366
,792.2283366
,792.7283366
,792.2283366
,792.7283366
,792.7283366
,792.7283366
,792.7283366
,792.2283366
,792.7283366
,792.7283366
,792.7283366
,792.7283366
,792.7283366
,792.7283366
,792.2283366
,792.7283366
,792.7283366
,792.7283366
,792.7283366
,792.7283366
,792.2283366
,792.7283366
,792.2283366
,792.2283366
,792.2283366
,764.0283366
,764.4283366
,765.2283366
,765.7283366
,765.7283366
,766.1283366
,766.5283366
,766.5283366
,766.9283366
,767.3283366
,767.3283366
,767.3283366
,767.8283366
,767.8283366
,767.8283366
,768.2283366
,768.2283366
,768.2283366
,768.2283366
,768.2283366
,767.8283366
,767.8283366
,768.2283366
,768.6283366
,768.6283366
,768.6283366
,768.6283366
,769.0283366
,769.0283366
,769.4283366
,769.4283366
,769.4283366
,769.4283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366
,770.3283366
,770.3283366
,770.3283366
,770.3283366
,770.3283366
,770.7283366
,770.7283366
,770.7283366
,770.7283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.6283366
,771.6283366
,772.0283366
,771.6283366
,771.6283366
,772.0283366
,772.0283366
,771.6283366
,771.6283366
,771.1283366
,771.6283366
,771.6283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,770.7283366
,770.7283366
,771.1283366
,771.1283366
,770.7283366
,770.7283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,770.7283366
,770.7283366
,770.7283366
,770.3283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366
,770.3283366
,770.3283366
,770.3283366
,770.3283366
,770.7283366
,770.7283366
,770.7283366
,770.7283366
,770.7283366
,770.7283366
,770.7283366
,770.7283366
,770.7283366
,771.1283366
,771.1283366
,770.7283366
,771.1283366
,771.1283366
,771.1283366
,771.6283366
,772.0283366
,772.0283366
,772.0283366
,772.0283366
,772.0283366
,772.0283366
,772.0283366
,772.4283366
,772.0283366
,771.6283366
,772.0283366
,771.6283366
,771.6283366
,771.6283366
,771.6283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,770.7283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,770.7283366
,771.1283366
,771.1283366
,771.1283366
,770.7283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,770.7283366
,770.7283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,770.7283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.6283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.6283366
,771.1283366
,772.0283366
,771.6283366
,771.6283366
,771.6283366
,771.6283366
,772.0283366
,772.0283366
,772.0283366
,771.6283366
,771.6283366
,771.6283366
,772.0283366
,772.0283366
,771.6283366
,771.6283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.6283366
,771.6283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,771.1283366
,770.7283366
,770.7283366
,770.3283366
,770.3283366
,770.3283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366
,769.9283366]

plt.plot (x,y)
plt.xlabel("Time (s)")
plt.ylabel("Pressure (mmHg)")
plt.title("The Time-Dependent Change in Pressure During the Adiabatic Expansion of Nitrogen Gas")
# Out:
# Text(0.5, 1.0, 'The Time-Dependent Change in Pressure During the Adiabatic Expansion of Nitrogen Gas')
